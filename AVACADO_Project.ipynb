# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn import svm as svc

# %%
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd
data = pd.read_csv('avocado.csv')
data
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# Showing howmany colums are there in the shared data

# %%
data.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# data.info shows the data which are similar

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# this shows the data shared, have no null values, so there is no need to perform the imputation.

# %%
data.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# Here the data.describe shows the mean, median, etc all the other values as shown in the table.

# %%
data.describe(include= 'all
# Out:
#           Unnamed: 0        Date  AveragePrice  Total Volume          4046  \
# count   18249.000000       18249  18249.000000  1.824900e+04  1.824900e+04
# unique           NaN         169           NaN           NaN           NaN
# top              NaN  2015-12-27           NaN           NaN           NaN
# freq             NaN         108           NaN           NaN           NaN
# mean       24.232232         NaN      1.405978  8.506440e+05  2.930084e+05
# std        15.481045         NaN      0.402677  3.453545e+06  1.264989e+06
# min         0.000000         NaN      0.440000  8.456000e+01  0.000000e+00
# 25%        10.000000         NaN      1.100000  1.083858e+04  8.540700e+02
# 50%        24.000000         NaN      1.370000  1.073768e+05  8.645300e+03
# 75%        38.000000         NaN      1.660000  4.329623e+05  1.110202e+05
# max        52.000000         NaN      3.250000  6.250565e+07  2.274362e+07
#
# ...

# %% [markdown]
# Now let us start EDA(Exploratory Data Analysis)

# %% [markdown]
# BASICS CHECKS....

# %% [markdown]
# Date - The date of the observation

# %% [markdown]
# AveragePrice - the average price of a single avocado

# %% [markdown]
# type - conventional or organic

# %% [markdown]
# Total Volume - Total number of avocados sold

# %% [markdown]
# Region - the city or region of the observation

# %% [markdown]
# 4046 - Total number of avocados with PLU 4046 sold
#
# 4770 - Total number of avocados with PLU 4770 sold
#
# 4225 - Total number of avocados with PLU 4225 sold

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x=data.AveragePrice)
plt.show()

# %% [markdown]
# Here we can see the how average price of the each avacado is increased in the countplot

# %%
sns.countplot(x=data.type )
plt.show()

# %% [markdown]
# Here the bar graph shows that, we two different types of avacadoes 1. Conventional avacado & 2. ORganic Avacadoes. with different count.

# %%
sns.countplot(x=data.year)
plt.show()

# %% [markdown]
# This bar graph shows that, in which year what is the count of productivity of the avacadors, the year on x axis and count on Y axis is clearlly shown. we can also see that in 2018 tha avacadoes count is very less.

# %% [markdown]
# LETS check with, Differnt types of Avacadoes and its price

# %%
sns.boxplot(x="AveragePrice", y="type", data=data,)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='type'>

# %% [markdown]
# Here is the display of organic & Conventional, we can see clearlly that Organic Avacado's price is little high than,Conventional avacadoes.

# %%
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
sns.histplot(x=data.AveragePrice, hue=data.region)
plt.show()

# %% [markdown]
# Here we can see that, how the Average price is been shown in differnt years

# %% [markdown]
# Now let us check the Classification of avacadoes, we have differnt types of classification

# %% [markdown]
# Logistic Regression

# %%
x=data

# %%
x
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
X=data[['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
       '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
       'year', 'region']]
y=data 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

print("X Train Shape ",X_train.shape)
print("Y Train Shape ",y_train.shape)

print("X Test Shape ",X_test.shape)
print("Y Test Shape ",y_test.shape)
# Out:
# X Train Shape  (14599, 14)
# Y Train Shape  (14599, 14)
# X Test Shape  (3650, 14)
# Y Test Shape  (3650, 14)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)

y_pred_train = logreg.predict(X_train)  
y_pred_test = logreg.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [77], in <cell line: 2>()
#       1 lr = LogisticRegression()
# ----> 2 lr.fit(X_train,y_train)
#       4 y_pred_train = logreg.predict(X_train)
#       5 y_pred_test = logreg.predict(X_test)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1508, in LogisticRegression.fit(self, X, y, sample_weight)
#    1505 else:
#    1506     _dtype = [np.float64, np.float32]
# -> 1508 X, y = self._validate_data(
#    1509     X,
#    1510     y,
#    1511     accept_sparse="csr",
#    1512     dtype=_dtype,
#    1513     order="C",
#    1514     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515 )
#    1516 check_classification_targets(y)
#    1517 self.classes_ = np.unique(y)
#
# ...
